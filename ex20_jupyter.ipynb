# %% [markdown]
# ### 주피터 노트북 시작
# - 마크 다운 쉘은 일반 md에서 작성하는것과 동일합니다.
# [구글](https://www.google.com/?hl=ko)
# - 주피터 노트북의 경로는 해당 위치 부터 시작

# %%
num = int(input('정수 입력 >'))

# %%
print(num)
# Out:
# 10

# %%
num
# Out:
# 10

# %%
print('Hello, Jupyter')
# Out:
# Hello, Jupyter

# %%
print(num)
num + 10
num *10
# Out:
# 100
